# %%
# Programmgeruest zu Versuch 1, Aufgabe 4)
import numpy as np
import pandas as pd
from time import clock
from random import randint
from V1A2_Classifier import *

# %%
# (I) Load data 
forestdata  = pd.read_csv('./Foresttypesdata.csv'); # load data as pandas data frame 
classlabels = ['s','h','d','o'];                                      # possible class labels (C=4) 
classidx    = {classlabels[i]:i for i in range(len(classlabels))}     # dict for mapping classlabel to index 
C           = len(classlabels)        # number of classes (Note: K is now the number of nearest-neighbors!!!!!!)
T_txt = forestdata.values[:,0]        # array of class labels of data vectors (class label is first data attribute)
X = forestdata.values[:,1:]           # array of feature vectors (features are remaining attributes)
T = [classidx[t.strip()] for t in T_txt]          # transform text labels 's','h','d','o' to numeric lables 0,1,2,3
N,D=X.shape                           # size and dimensionality of data set
print("Data set 'ForestData' has size N=", N, " and dimensionality D=",D, " and C=", C, " different classes")
print("X[0..9]=\n",X[0:10])
print("T_txt[0..9]=\n",T_txt[0:10])
print("T[0..9]=\n",T[0:10])
# Out:
# Data set 'ForestData' has size N= 523  and dimensionality D= 27  and C= 4  different classes
# X[0..9]=
#  [[39 36 57 91 59 101 93 27 60 75.7 14.86 40.35 7.97 -32.92 -38.92 -14.94
#   4.47 -2.36 -18.41 -1.88 -6.43 -21.03 -1.6 -6.18 -22.5 -5.2 -7.86]
#  [84 30 57 112 51 98 92 26 62 30.58 20.42 39.83 -16.74 -24.92 -36.33 -15.67
#   8.16 -2.26 -16.27 -1.95 -6.25 -18.79 -1.99 -6.18 -23.41 -8.87 -10.83]
#  [53 25 49 99 51 93 84 26 58 63.2 26.7 49.28 3.25 -24.89 -30.38 -3.6 4.15
#   -1.46 -15.92 -1.79 -4.64 -17.73 -0.48 -4.69 -19.97 -4.1 -7.07]
#  [59 26 49 103 47 92 82 25 56 55.54 24.5 47.9 -6.2 -20.98 -30.28 -5.03 7.77
#   2.68 -13.77 -2.53 -6.34 -22.03 -2.34 -6.6 -27.1 -7.99 -10.81]
#  [57 49 66 103 64 106 114 28 59 59.44 2.62 32.02 -1.33 -37.99 -43.57 -34.25
#   1.83 -2.94 -21.74 -1.64 -4.62 -23.74 -0.85 -5.5 -22.83 -2.74 -5.84]
#  [85 28 56 120 52 98 101 27 65 35.14 23.43 42.29 -16.58 -25.43 -34.14
#   -17.45 1.58 -10.28 -26.18 -1.89 -5.89 -34.92 -1.89 -8.05 -29.72 -1.94
#   -4.94]
#  [56 29 50 93 51 94 77 26 58 62.5 22.48 48.2 9.69 -24.78 -30.81 3.91 3.09
#   -2.68 -26.33 -0.55 -3.89 -23.84 0.02 -4.2 -23.17 -0.22 -4.22]
#  [40 39 58 82 61 99 89 26 57 73.99 12.91 41.92 17.33 -34.82 -36.19 -11.07
#   4.28 -0.19 -18.72 -2.61 -8.38 -20.56 -1.51 -6.68 -21.16 -3.42 -6.61]
#  [53 27 49 95 49 92 63 25 54 66.97 24.43 49.28 8.08 -22.53 -28.25 19.78
#   3.75 0.92 -25.65 -2.09 -5.95 -39.27 -2.13 -8.73 -30.73 -2.42 -5.58]
#  [51 57 77 90 89 123 97 47 83 64.91 -5.21 21.45 12.21 -62.9 -60.4 -16.75
#   -16.85 -26.44 -20.97 -1.76 -5.05 -22.01 -0.93 -5.6 -22.26 -3.28 -6.39]]
# T_txt[0..9]=
#  ['d ' 'h ' 's ' 's ' 'd ' 'h ' 's ' 'd ' 's ' 'o ']
# T[0..9]=
#  [2, 1, 0, 0, 2, 1, 0, 2, 0, 3]

# %% [markdown]
# # b)

# %%
# (II) Test KNN-classifier with S-fold cross validation
S_list=[5]                            # parameter S for cross validation; INSERT appropriate values
K_list=[3]                            # number K of nearest neighbors; INSERT appropriate values
accuracy = np.zeros((len(S_list),len(K_list)));   # array to save accuracy of classifier for each value of S and K
for i in range(len(S_list)):
    S=S_list[i]                      # do an S-fold cross validation
    for j in range(len(K_list)):
        K=K_list[j]
        t1=clock()                   # start time
        knnc = FastKNNClassifier(4,K)            # REPLACE! create appropriate KNN classifier (with kd-trees) 
        pE,pCE = knnc.crossvalidate(S,X,T)      # REPLACE! Do S-fold cross validation and get error probabilities / confusion matrix
        t2=clock()                            # end time
        time_comp=t2-t1                       # computing time in seconds
        print( "\nS=",S," fold cross validation using the",K,"-NNClassifier with KD-Trees yields the following results:")
        print( "Classification error probability = ", pE)
        print( "Accuracy = ", 1.0-pE)
        print( "Confusion Error Probabilities p(class i|class j) = \n", pCE)
        print( "Computing time = ", time_comp, " sec")
        accuracy[i,j]=1.0-pE
print( "\naccuracy=\n",accuracy)
print( "\np_classerror=\n",1.0-accuracy)
# Out:
# S= 5  fold cross validation using the 3 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.14340344168260039
# Accuracy =  0.8565965583173996
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.8974359   0.12790698  0.05031447  0.01204819]
#  [ 0.06666667  0.84883721  0.02515723  0.        ]
#  [ 0.03589744  0.02325581  0.86163522  0.22891566]
#  [ 0.          0.          0.06289308  0.75903614]]
# Computing time =  2.180394  sec
#
# accuracy=
#  [[ 0.85659656]]
#
# p_classerror=
#  [[ 0.14340344]]

# %% [markdown]
# # c)

# %%
# (II) Test KNN-classifier with S-fold cross validation
S_list=[1, 2, 3, 5, 10, 100]                            # parameter S for cross validation; INSERT appropriate values
K_list=[2,3,4,5,10,15,20]                            # number K of nearest neighbors; INSERT appropriate values
accuracy = np.zeros((len(S_list),len(K_list)));   # array to save accuracy of classifier for each value of S and K
for i in range(len(S_list)):
    S=S_list[i]                      # do an S-fold cross validation
    for j in range(len(K_list)):
        K=K_list[j]
        t1=clock()                   # start time
        knnc = FastKNNClassifier(4,K)            # REPLACE! create appropriate KNN classifier (with kd-trees) 
        pE,pCE = knnc.crossvalidate(S,X,T)      # REPLACE! Do S-fold cross validation and get error probabilities / confusion matrix
        t2=clock()                            # end time
        time_comp=t2-t1                       # computing time in seconds
        print( "\nS=",S," fold cross validation using the",K,"-NNClassifier with KD-Trees yields the following results:")
        print( "Classification error probability = ", pE)
        print( "Accuracy = ", 1.0-pE)
        print( "Confusion Error Probabilities p(class i|class j) = \n", pCE)
        print( "Computing time = ", time_comp, " sec")
        accuracy[i,j]=1.0-pE
print( "\naccuracy=\n",accuracy)
print( "\np_classerror=\n",1.0-accuracy)
# Out:
# S= 1  fold cross validation using the 2 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.07074569789674952
# Accuracy =  0.9292543021032504
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.95384615  0.06976744  0.03773585  0.01204819]
#  [ 0.03076923  0.91860465  0.          0.        ]
#  [ 0.01538462  0.01162791  0.93710692  0.12048193]
#  [ 0.          0.          0.02515723  0.86746988]]
# Computing time =  1.937564  sec
#
# S= 1  fold cross validation using the 3 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.09177820267686425
# Accuracy =  0.9082217973231358
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.92820513  0.06976744  0.04402516  0.01204819]
#  [ 0.03589744  0.93023256  0.          0.        ]
#  [ 0.03076923  0.          0.89937107  0.13253012]
#  [ 0.00512821  0.          0.05660377  0.85542169]]
# Computing time =  2.3921669999999997  sec
#
# S= 1  fold cross validation using the 4 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.124282982791587
# Accuracy =  0.875717017208413
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.89230769  0.12790698  0.03773585  0.03614458]
#  [ 0.03589744  0.86046512  0.00628931  0.        ]
#  [ 0.07179487  0.01162791  0.9245283   0.20481928]
#  [ 0.          0.          0.03144654  0.75903614]]
# Computing time =  2.6343819999999987  sec
#
# S= 1  fold cross validation using the 5 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.12810707456978968
# Accuracy =  0.8718929254302104
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.93846154  0.11627907  0.0754717   0.03614458]
#  [ 0.03076923  0.88372093  0.00628931  0.        ]
#  [ 0.03076923  0.          0.83018868  0.18072289]
#  [ 0.          0.          0.08805031  0.78313253]]
# Computing time =  2.899666  sec
#
# S= 1  fold cross validation using the 10 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.17782026768642448
# Accuracy =  0.8221797323135756
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.93333333  0.22093023  0.10062893  0.02409639]
#  [ 0.03076923  0.77906977  0.          0.        ]
#  [ 0.03589744  0.          0.7672956   0.26506024]
#  [ 0.          0.          0.13207547  0.71084337]]
# Computing time =  3.3476479999999995  sec
#
# S= 1  fold cross validation using the 15 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.124282982791587
# Accuracy =  0.875717017208413
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.90769231  0.12790698  0.06289308  0.01204819]
#  [ 0.05641026  0.87209302  0.          0.        ]
#  [ 0.02564103  0.          0.89308176  0.21686747]
#  [ 0.01025641  0.          0.04402516  0.77108434]]
# Computing time =  3.9619290000000014  sec
#
# S= 1  fold cross validation using the 20 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.13766730401529637
# Accuracy =  0.8623326959847036
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.94871795  0.15116279  0.08176101  0.03614458]
#  [ 0.03076923  0.84883721  0.00628931  0.        ]
#  [ 0.02051282  0.          0.87421384  0.31325301]
#  [ 0.          0.          0.03773585  0.65060241]]
# Computing time =  3.8592709999999997  sec
#
# S= 2  fold cross validation using the 2 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.13001912045889102
# Accuracy =  0.869980879541109
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.91282051  0.12790698  0.0754717   0.02409639]
#  [ 0.06153846  0.86046512  0.00628931  0.        ]
#  [ 0.02051282  0.01162791  0.88050314  0.21686747]
#  [ 0.00512821  0.          0.03773585  0.75903614]]
# Computing time =  1.6373999999999995  sec
#
# S= 2  fold cross validation using the 3 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.16252390057361377
# Accuracy =  0.8374760994263862
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.84102564  0.12790698  0.09433962  0.03614458]
#  [ 0.07692308  0.86046512  0.00628931  0.01204819]
#  [ 0.08205128  0.01162791  0.8427673   0.15662651]
#  [ 0.          0.          0.05660377  0.79518072]]
# Computing time =  1.6988089999999971  sec
#
# S= 2  fold cross validation using the 4 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.1988527724665392
# Accuracy =  0.8011472275334608
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.85128205  0.22093023  0.12578616  0.03614458]
#  [ 0.07692308  0.76744186  0.          0.        ]
#  [ 0.06666667  0.01162791  0.79874214  0.24096386]
#  [ 0.00512821  0.          0.0754717   0.72289157]]
# Computing time =  1.8249679999999984  sec
#
# S= 2  fold cross validation using the 5 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.1701720841300191
# Accuracy =  0.8298279158699808
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.8974359   0.31395349  0.08176101  0.03614458]
#  [ 0.06153846  0.68604651  0.          0.        ]
#  [ 0.04102564  0.          0.89308176  0.26506024]
#  [ 0.          0.          0.02515723  0.69879518]]
# Computing time =  2.0586629999999957  sec
#
# S= 2  fold cross validation using the 10 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.19120458891013384
# Accuracy =  0.8087954110898662
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.92307692  0.20930233  0.11949686  0.04819277]
#  [ 0.03589744  0.77906977  0.          0.        ]
#  [ 0.02564103  0.01162791  0.70440252  0.18072289]
#  [ 0.01538462  0.          0.17610063  0.77108434]]
# Computing time =  2.8708820000000017  sec
#
# S= 2  fold cross validation using the 15 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.22179732313575526
# Accuracy =  0.7782026768642447
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.94358974  0.47674419  0.10691824  0.02409639]
#  [ 0.02564103  0.52325581  0.01257862  0.        ]
#  [ 0.03076923  0.          0.74842767  0.26506024]
#  [ 0.          0.          0.13207547  0.71084337]]
# Computing time =  2.501683  sec
#
# S= 2  fold cross validation using the 20 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.2237093690248566
# Accuracy =  0.7762906309751434
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.82564103  0.1627907   0.18238994  0.03614458]
#  [ 0.14871795  0.8255814   0.01257862  0.01204819]
#  [ 0.02564103  0.01162791  0.78616352  0.36144578]
#  [ 0.          0.          0.01886792  0.59036145]]
# Computing time =  2.4276219999999995  sec
#
# S= 3  fold cross validation using the 2 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.12810707456978968
# Accuracy =  0.8718929254302104
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.92307692  0.12790698  0.0754717   0.03614458]
#  [ 0.02564103  0.87209302  0.00628931  0.        ]
#  [ 0.05128205  0.          0.8490566   0.1686747 ]
#  [ 0.          0.          0.06918239  0.79518072]]
# Computing time =  1.7735969999999952  sec
#
# S= 3  fold cross validation using the 3 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.17208413001912046
# Accuracy =  0.8279158699808795
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.87692308  0.20930233  0.0754717   0.02409639]
#  [ 0.06153846  0.79069767  0.          0.        ]
#  [ 0.05128205  0.          0.83018868  0.22891566]
#  [ 0.01025641  0.          0.09433962  0.74698795]]
# Computing time =  1.994848999999995  sec
#
# S= 3  fold cross validation using the 4 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.16443594646271512
# Accuracy =  0.8355640535372849
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.84102564  0.1744186   0.06918239  0.        ]
#  [ 0.08717949  0.81395349  0.00628931  0.        ]
#  [ 0.06666667  0.01162791  0.87421384  0.22891566]
#  [ 0.00512821  0.          0.05031447  0.77108434]]
# Computing time =  2.2114150000000024  sec
# S= 3  fold cross validation using the 5 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.16061185468451242
# Accuracy =  0.8393881453154876
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.88205128  0.12790698  0.08176101  0.03614458]
#  [ 0.07692308  0.87209302  0.01257862  0.        ]
#  [ 0.04102564  0.          0.82389937  0.22891566]
#  [ 0.          0.          0.08176101  0.73493976]]
# Computing time =  2.5522080000000003  sec
#
# S= 3  fold cross validation using the 10 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.22179732313575526
# Accuracy =  0.7782026768642447
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.82051282  0.1627907   0.05660377  0.02409639]
#  [ 0.12307692  0.8255814   0.01886792  0.        ]
#  [ 0.05128205  0.01162791  0.79245283  0.37349398]
#  [ 0.00512821  0.          0.13207547  0.60240964]]
# Computing time =  2.673912999999999  sec
#
# S= 3  fold cross validation using the 15 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.17973231357552583
# Accuracy =  0.8202676864244742
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.85641026  0.11627907  0.06918239  0.04819277]
#  [ 0.07692308  0.81395349  0.01257862  0.        ]
#  [ 0.06153846  0.06976744  0.81761006  0.20481928]
#  [ 0.00512821  0.          0.10062893  0.74698795]]
# Computing time =  2.8126319999999936  sec
#
# S= 3  fold cross validation using the 20 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.20076481835564053
# Accuracy =  0.7992351816443595
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.86153846  0.24418605  0.08805031  0.06024096]
#  [ 0.08205128  0.75581395  0.01257862  0.02409639]
#  [ 0.05128205  0.          0.82389937  0.26506024]
#  [ 0.00512821  0.          0.0754717   0.65060241]]
# Computing time =  3.2781090000000006  sec
#
# S= 5  fold cross validation using the 2 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.14149139579349904
# Accuracy =  0.858508604206501
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.9025641   0.13953488  0.05660377  0.01204819]
#  [ 0.06666667  0.8372093   0.01886792  0.        ]
#  [ 0.02051282  0.02325581  0.86792453  0.22891566]
#  [ 0.01025641  0.          0.05660377  0.75903614]]
# Computing time =  2.4280720000000002  sec
#
# S= 5  fold cross validation using the 3 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.1491395793499044
# Accuracy =  0.8508604206500956
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.87179487  0.1627907   0.05031447  0.01204819]
#  [ 0.06666667  0.80232558  0.01257862  0.        ]
#  [ 0.05641026  0.03488372  0.88050314  0.19277108]
#  [ 0.00512821  0.          0.05660377  0.79518072]]
# Computing time =  2.6023950000000013  sec
#
# S= 5  fold cross validation using the 4 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.16634799235181644
# Accuracy =  0.8336520076481836
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.84615385  0.15116279  0.06289308  0.03614458]
#  [ 0.08717949  0.84883721  0.00628931  0.        ]
#  [ 0.06153846  0.          0.85534591  0.21686747]
#  [ 0.00512821  0.          0.0754717   0.74698795]]
# Computing time =  3.3650049999999965  sec
#
# S= 5  fold cross validation using the 5 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.15487571701720843
# Accuracy =  0.8451242829827916
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.88205128  0.19767442  0.0754717   0.03614458]
#  [ 0.05128205  0.75581395  0.00628931  0.        ]
#  [ 0.06666667  0.04651163  0.88679245  0.19277108]
#  [ 0.          0.          0.03144654  0.77108434]]
# Computing time =  3.5220020000000005  sec
#
# S= 5  fold cross validation using the 10 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.16634799235181644
# Accuracy =  0.8336520076481836
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.89230769  0.23255814  0.04402516  0.02409639]
#  [ 0.05128205  0.76744186  0.01886792  0.        ]
#  [ 0.05641026  0.          0.88679245  0.31325301]
#  [ 0.          0.          0.05031447  0.6626506 ]]
# Computing time =  3.3242270000000076  sec
#
# S= 5  fold cross validation using the 15 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.19694072657743786
# Accuracy =  0.8030592734225621
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.90769231  0.22093023  0.14465409  0.08433735]
#  [ 0.02564103  0.77906977  0.          0.01204819]
#  [ 0.06153846  0.          0.72955975  0.18072289]
#  [ 0.00512821  0.          0.12578616  0.72289157]]
# Computing time =  3.6105270000000047  sec
#
# S= 5  fold cross validation using the 20 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.1931166347992352
# Accuracy =  0.8068833652007648
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.9025641   0.20930233  0.11949686  0.03614458]
#  [ 0.04102564  0.73255814  0.00628931  0.        ]
#  [ 0.05128205  0.05813953  0.81761006  0.3253012 ]
#  [ 0.00512821  0.          0.05660377  0.63855422]]
# Computing time =  4.263469999999998  sec
#
# S= 10  fold cross validation using the 2 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.13193116634799235
# Accuracy =  0.8680688336520077
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.8974359   0.12790698  0.05031447  0.02409639]
#  [ 0.06153846  0.87209302  0.01257862  0.        ]
#  [ 0.03076923  0.          0.87421384  0.19277108]
#  [ 0.01025641  0.          0.06289308  0.78313253]]
# Computing time =  2.3300389999999993  sec
#
# S= 10  fold cross validation using the 3 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.14149139579349904
# Accuracy =  0.858508604206501
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.88205128  0.13953488  0.06918239  0.02409639]
#  [ 0.08717949  0.84883721  0.00628931  0.        ]
#  [ 0.03076923  0.01162791  0.86792453  0.18072289]
#  [ 0.          0.          0.05660377  0.79518072]]
# Computing time =  2.5930100000000067  sec
#
# S= 10  fold cross validation using the 4 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.1491395793499044
# Accuracy =  0.8508604206500956
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.84615385  0.05813953  0.0754717   0.01204819]
#  [ 0.09230769  0.93023256  0.01886792  0.        ]
#  [ 0.05641026  0.01162791  0.8490566   0.20481928]
#  [ 0.00512821  0.          0.05660377  0.78313253]]
# Computing time =  2.997614999999996  sec
#
# S= 10  fold cross validation using the 5 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.14340344168260039
# Accuracy =  0.8565965583173996
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.89230769  0.13953488  0.05031447  0.02409639]
#  [ 0.05128205  0.86046512  0.01257862  0.        ]
#  [ 0.05128205  0.          0.88050314  0.25301205]
#  [ 0.00512821  0.          0.05660377  0.72289157]]
# Computing time =  2.9774829999999923  sec
#
# S= 10  fold cross validation using the 10 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.1491395793499044
# Accuracy =  0.8508604206500956
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.89230769  0.12790698  0.09433962  0.02409639]
#  [ 0.07179487  0.87209302  0.00628931  0.        ]
#  [ 0.03076923  0.          0.86163522  0.26506024]
#  [ 0.00512821  0.          0.03773585  0.71084337]]
# Computing time =  3.7224369999999993  sec
#
# S= 10  fold cross validation using the 15 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.22753346080305928
# Accuracy =  0.7724665391969407
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.9025641   0.1627907   0.11949686  0.        ]
#  [ 0.05641026  0.8372093   0.          0.        ]
#  [ 0.03589744  0.          0.62893082  0.3253012 ]
#  [ 0.00512821  0.          0.25157233  0.6746988 ]]
# Computing time =  3.4532799999999924  sec
# S= 10  fold cross validation using the 20 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.21032504780114722
# Accuracy =  0.7896749521988528
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.84102564  0.20930233  0.10691824  0.01204819]
#  [ 0.04102564  0.79069767  0.          0.        ]
#  [ 0.11794872  0.          0.83018868  0.39759036]
#  [ 0.          0.          0.06289308  0.59036145]]
# Computing time =  3.635953999999998  sec
#
# S= 100  fold cross validation using the 2 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.1338432122370937
# Accuracy =  0.8661567877629063
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.89230769  0.10465116  0.05660377  0.02409639]
#  [ 0.06153846  0.89534884  0.01886792  0.        ]
#  [ 0.04102564  0.          0.86163522  0.19277108]
#  [ 0.00512821  0.          0.06289308  0.78313253]]
# Computing time =  4.6757300000000015  sec
#
# S= 100  fold cross validation using the 3 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.12045889101338432
# Accuracy =  0.8795411089866156
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.92307692  0.10465116  0.06289308  0.01204819]
#  [ 0.05128205  0.89534884  0.00628931  0.        ]
#  [ 0.02051282  0.          0.85534591  0.18072289]
#  [ 0.00512821  0.          0.0754717   0.80722892]]
# Computing time =  4.892589999999998  sec
#
# S= 100  fold cross validation using the 4 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.13001912045889102
# Accuracy =  0.869980879541109
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.9025641   0.12790698  0.05660377  0.02409639]
#  [ 0.05128205  0.84883721  0.00628931  0.        ]
#  [ 0.04102564  0.02325581  0.89308176  0.20481928]
#  [ 0.00512821  0.          0.04402516  0.77108434]]
# Computing time =  5.028000000000006  sec
#
# S= 100  fold cross validation using the 5 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.11281070745697896
# Accuracy =  0.887189292543021
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.93846154  0.13953488  0.05660377  0.04819277]
#  [ 0.04102564  0.86046512  0.          0.        ]
#  [ 0.02051282  0.          0.87421384  0.13253012]
#  [ 0.          0.          0.06918239  0.81927711]]
# Computing time =  5.202106999999998  sec
#
# S= 100  fold cross validation using the 10 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.16443594646271512
# Accuracy =  0.8355640535372849
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.91794872  0.18604651  0.10062893  0.03614458]
#  [ 0.04615385  0.81395349  0.00628931  0.        ]
#  [ 0.01538462  0.          0.83647799  0.30120482]
#  [ 0.02051282  0.          0.05660377  0.6626506 ]]
# Computing time =  5.599155999999994  sec
#
# S= 100  fold cross validation using the 15 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.15678776290630975
# Accuracy =  0.8432122370936903
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.91282051  0.24418605  0.08176101  0.02409639]
#  [ 0.03589744  0.74418605  0.          0.        ]
#  [ 0.05128205  0.01162791  0.85534591  0.21686747]
#  [ 0.          0.          0.06289308  0.75903614]]
# Computing time =  5.902014000000008  sec
#
# S= 100  fold cross validation using the 20 -NNClassifier with KD-Trees yields the following results:
# Classification error probability =  0.18929254302103252
# Accuracy =  0.8107074569789675
# Confusion Error Probabilities p(class i|class j) =
#  [[ 0.90769231  0.11627907  0.08805031  0.02409639]
#  [ 0.06153846  0.88372093  0.00628931  0.        ]
#  [ 0.01025641  0.          0.77358491  0.39759036]
#  [ 0.02051282  0.          0.13207547  0.57831325]]
# Computing time =  6.166247999999996  sec
#
# accuracy=
#  [[ 0.9292543   0.9082218   0.87571702  0.87189293  0.82217973  0.87571702
#    0.8623327 ]
#  [ 0.86998088  0.8374761   0.80114723  0.82982792  0.80879541  0.77820268
#    0.77629063]
#  [ 0.87189293  0.82791587  0.83556405  0.83938815  0.77820268  0.82026769
#    0.79923518]
#  [ 0.8585086   0.85086042  0.83365201  0.84512428  0.83365201  0.80305927
#    0.80688337]
#  [ 0.86806883  0.8585086   0.85086042  0.85659656  0.85086042  0.77246654
#    0.78967495]
#  [ 0.86615679  0.87954111  0.86998088  0.88718929  0.83556405  0.84321224
#    0.81070746]]
#
# p_classerror=
#  [[ 0.0707457   0.0917782   0.12428298  0.12810707  0.17782027  0.12428298
#    0.1376673 ]
#  [ 0.13001912  0.1625239   0.19885277  0.17017208  0.19120459  0.22179732
#    0.22370937]
#  [ 0.12810707  0.17208413  0.16443595  0.16061185  0.22179732  0.17973231
#    0.20076482]
#  [ 0.1414914   0.14913958  0.16634799  0.15487572  0.16634799  0.19694073
#    0.19311663]
#  [ 0.13193117  0.1414914   0.14913958  0.14340344  0.14913958  0.22753346
#    0.21032505]
#  [ 0.13384321  0.12045889  0.13001912  0.11281071  0.16443595  0.15678776
#    0.18929254]]

# %% [markdown]
# # d)

# %% [markdown]
# Man könnte die Trainingsdaten als implizierte Parameter verstehen, auch die Art wie ein kd-Tree gebildet wird (Median oder Mittelwert ?) ist eine Art Parameter
